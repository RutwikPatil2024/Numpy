# %%
import numpy as np

# %%
arr=np.array([10,20,30,40,50,60])
print(arr)
# Out:
# [10 20 30 40 50 60]

# %%
brr=arr.view()
brr
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
arr[0]=777
print(arr)
print(brr)
# Out:
# [777  20  30  40  50  60]
# [777  20  30  40  50  60]

# %%
brr[2]=1000
print(arr)
print(brr)
# Out:
# [ 777   20 1000   40   50   60]
# [ 777   20 1000   40   50   60]

# %%
arr=np.array([1,2,3,4,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
brr=arr.copy()
brr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr[0]=888
print(arr)
print(brr)
# Out:
# [888   2   3   4   5   6]
# [1 2 3 4 5 6]

# %%
brr[1]=1000
print(arr)
print(brr)
# Out:
# [888   2   3   4   5   6]
# [   1 1000    3    4    5    6]
