# %%
import numpy as np

# %%
arr=np.array([[10,20],[30,40]])
arr
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
brr=np.array([[1,2],[3,4]])
brr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr*brr
# Out:
# array([[ 10,  40],
#        [ 90, 160]])

# %%
arr=np.matrix(arr)

# %%
arr
# Out:
# matrix([[10, 20],
#         [30, 40]])

# %%
brr=np.matrix(brr)
brr
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
arr*brr
# Out:
# matrix([[ 70, 100],
#         [150, 220]])

# %%
arr=np.array([[10,20],[30,40]])
arr
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
brr=np.array([[1,2],[3,4]])
brr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.dot(arr,brr)
# Out:
# array([[ 70, 100],
#        [150, 220]])
