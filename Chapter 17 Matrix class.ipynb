# %%
import numpy as np

# %%
arr=np.array([[1,2],[3,4]])
arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
brr=np.array([[10,20],[30,40]])
brr
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
arr+brr
# Out:
# matrix([[11, 22],
#         [33, 44]])

# %%
arr*brr
# Out:
# array([[ 10,  40],
#        [ 90, 160]])

# %%
arrm=np.matrix(arr)

# %%
arrm
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
brrm=np.matrix(brr)

# %%
brrm
# Out:
# matrix([[10, 20],
#         [30, 40]])

# %%
arr*brr
# Out:
# matrix([[ 70, 100],
#         [150, 220]])

# %%
arrm
